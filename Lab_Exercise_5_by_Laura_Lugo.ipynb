# %% [markdown]
# <a href="https://colab.research.google.com/github/Lauralug0/Facebook/blob/main/Lab_Exercise_5_by_Laura_Lugo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <p style="font-family: Arial; font-size:3em;color:black;"> Lab Exercise 6</p>

# %% [markdown]
# The process below shows how to implement a simple linear regression analysis for a vehicle pricing scenario. Re-run it and take note of the R-sqaured value. Then. change the std value in np.random.normal to 1, 5 and 10. Observe the change in R-sqaured. How do you explain the change in R-sqaured value?

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

vehicle_age = np.random.uniform(0,10,1000)
vehicle_price = 70000 - (vehicle_age + np.random.normal(0, 1, 1000)) * 3000

vehicle_age = vehicle_age.reshape(-1, 1)  #reshape for single feature, use (1,-1) for single sample
vehicle_price = vehicle_price.reshape(-1, 1)

plt.scatter(vehicle_age, vehicle_price)

print ( "When there are variations in the deviations (1, 5, 10) we can see that it introduces a lot more scatter into your data. Also, the value of R2 will decrease")


#0.893653838685212 @ 1
#0.21949923163284668 @ 5
#0.060627905713471986 @ 10


data = {
    'Deviation': [1, 5, 10],
    'R²': [0.893653838685212, 0.21949923163284668 , 0.060627905713471986]
}

# Create DataFrame
df = pd.DataFrame(data)

# Display the table
print(df)
# Out:
# When there are variations in the deviations (1, 5, 10) we can see that it introduces a lot more scatter into your data. Also, the value of R2 will decrease
#    Deviation        R²
# 0          1  0.893654
# 1          5  0.219499
# 2         10  0.060628

# %%
reg = LinearRegression().fit(vehicle_age, vehicle_price)
reg.score(vehicle_age, vehicle_price)
# Out:
# 0.8918201876466726
